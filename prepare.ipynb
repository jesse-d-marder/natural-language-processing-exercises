# %%
import unicodedata
import re
import json

import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords

import pandas as pd

import acquire
import prepare

# %%
codeup_df = prepare.create_prepared_blog_df()

# %%
codeup_df.head()
# Out:
#                                                  url  \
# 0  https://codeup.com/workshops/from-bootcamp-to-...
# 1  https://codeup.com/featured/our-acquisition-of...
# 2  https://codeup.com/workshops/virtual/learn-to-...
# 3  https://codeup.com/workshops/virtual/learn-to-...
# 4  https://codeup.com/codeup-news/coming-soon-clo...
#
#                                                title date_published  \
# 0  From Bootcamp to Bootcamp | A Military Appreci...   Apr 27, 2022
# 1  Our Acquisition of the Rackspace Cloud Academy...   Apr 14, 2022
# 2  Learn to Code: HTML & CSS on 4/30\nApr 1, 2022...    Apr 1, 2022
# 3  Learn to Code: Python Workshop on 4/23\nMar 31...   Mar 31, 2022
# 4  Coming Soon: Cloud Administration\nMar 17, 202...   Mar 17, 2022
#
#                                             original  \
# 0  In honor of Military Appreciation Month, join ...
# 1  Just about a year ago on April 16th, 2021 we a...
# 2  HTML & CSS are the design building blocks of a...
# ...

# %%
news_df = prepare.create_prepared_news_df()
# Out:
# Importing from csv

# %%
news_df.lemmatized[3]
# Out:
# "two people including toddler charred death two others family suffered critical burn injury car travelling hit culvert caught fire rajasthan ' baran monday incident took place family returning home kota attending engagement ceremony"

# %%
df = acquire.get_blog_articles(True)

# %%
df = pd.DataFrame(df)

# %%
original = df.original[0]

# %%
article = original.lower()

# %%
print(prepare.basic_clean(article))
# Out:
# in honor of military appreciation month join us for a discussion with codeup alumni who are also military veterans we will chat about their experiences attending a coding bootcamp and how their military training set them up for success here at codeup grab your virtual seat now so you can be sent the exclusive livestream link on the 11th
# thank you to our panelists for participating
#
# christopher aguirre
# taryn mckenzie
# desiree mcelroy
#
#
# and thanks to codeups trey iapachino who is also an air force veteran

# %%
tokenizer = nltk.tokenize.ToktokTokenizer()

print(tokenizer.tokenize(original, return_str=True))
# Out:
# In honor of Military Appreciation Month , join us for a discussion with Codeup Alumni who are also Military Veterans ! We will chat about their experiences attending a coding bootcamp , and how their military training set them up for success here at Codeup. Grab your virtual seat now so you can be sent the exclusive Livestream link on the 11th !
# Thank you to our panelists for participating :
#
# Christopher Aguirre
# Taryn McKenzie
# Desiree McElroy
#
#
# And thanks to Codeup ’ s Trey Iapachino who is also an Air Force Veteran !

# %%
stems = prepare.stem(original)

# %%
stems
# Out:
# 'in honor of militari appreci month, join us for a discuss with codeup alumni who are also militari veterans! we will chat about their experi attend a code bootcamp, and how their militari train set them up for success here at codeup. grab your virtual seat now so you can be sent the exclus livestream link on the 11th! thank you to our panelist for participating: christoph aguirr taryn mckenzi desire mcelroy and thank to codeup’ trey iapachino who is also an air forc veteran!'

# %%
prepare.lemmatize(original)
# Out:
# 'In honor of Military Appreciation Month, join u for a discussion with Codeup Alumni who are also Military Veterans! We will chat about their experience attending a coding bootcamp, and how their military training set them up for success here at Codeup. Grab your virtual seat now so you can be sent the exclusive Livestream link on the 11th! Thank you to our panelist for participating: Christopher Aguirre Taryn McKenzie Desiree McElroy And thanks to Codeup’s Trey Iapachino who is also an Air Force Veteran!'

# %%
original
# Out:
# 'In honor of Military Appreciation Month, join us for a discussion with Codeup Alumni who are also Military Veterans! We will chat about their experiences attending a coding bootcamp, and how their military training set them up for success here at Codeup. Grab your virtual seat now so you can be sent the exclusive Livestream link on the 11th! \nThank you to our panelists for participating: \n\nChristopher Aguirre\nTaryn McKenzie \nDesiree McElroy \n\n\nAnd thanks to Codeup’s Trey Iapachino who is also an Air Force Veteran!'

# %%
prepare.remove_stopwords(original, extra_words = ['Taryn', 'Month','chat'], exclude_words= ['for','We'])
# Out:
# Removed 34 stopwords
# 'In honor Military Appreciation Month, join us for discussion Codeup Alumni also Military Veterans! We experiences attending coding bootcamp, military training set for success Codeup. Grab virtual seat sent exclusive Livestream link 11th! Thank panelists for participating: Christopher Aguirre McKenzie Desiree McElroy And thanks Codeup’s Trey Iapachino also Air Force Veteran!'

# %% [markdown]
# ### 6. Produce df of news articles named news_df

# %%
news_df = acquire.get_news_articles()
# Out:
# Importing from csv

# %%
news_df = pd.DataFrame(news_df)

# %%
news_df
# Out:
#                                                  title             author  \
# 0    Delhi sees less than 1,000 new COVID-19 cases,...      Deepika Bhatt
# 1    Parts of Mumbai face power outages due to tech...  Shreyasi Banerjee
# 2    CBI books former staff member of TMC MLA Babul...  Shreyasi Banerjee
# 3    2, including toddler, burnt alive as car catch...  Shreyasi Banerjee
# 4    11 fishermen stranded in Odisha sea airlifted ...  Shreyasi Banerjee
# ..                                                 ...                ...
# 294  Mercedes looking at energy options should Russ...  Aishwarya Awasthi
# 295  Saudi Arabia to buy 1 lakh EVs over 10 yrs: Lu...  Aishwarya Awasthi
# 296  Pune has best environment to become an automob...       Medhaa Gupta
# 297  18-year-old boy develops AI, sensor-based bicy...     Dharini Mudgal
# 298  Tata aims to build 80,000 EVs this financial y...  Aishwarya Awasthi
#
#                      datetime    category  \
# ...

# %% [markdown]
# ### 7 codeup blog post dataframe

# %%
# codeup_df = acquire.get_blog_articles()

# %%
# codeup_df = pd.DataFrame(codeup_df)

# %%
# prepare.basic_clean(codeup_df.original[0])

# %%
# codeup_df['clean'] = codeup_df.apply(lambda row: prepare.basic_clean(row.original), axis=1)

# codeup_df['stemmed'] = codeup_df.apply(lambda row: prepare.stem(row.clean), axis=1)

# codeup_df['lemmatized'] = codeup_df.apply(lambda row: prepare.lemmatize(row.clean), axis=1)

# %%
# Out:
# Removed 38 stopwords
# Removed 327 stopwords
# Removed 32 stopwords
# Removed 73 stopwords
# Removed 154 stopwords
# Removed 465 stopwords
# Removed 128 stopwords
# Removed 158 stopwords
# Removed 95 stopwords
# Removed 174 stopwords
# Removed 278 stopwords
# Removed 154 stopwords
# Removed 379 stopwords
# Removed 218 stopwords
# Removed 253 stopwords
# Removed 339 stopwords
# Removed 184 stopwords

# %%
codeup_df.head(5)
# Out:
#                                                  url  \
# 0  https://codeup.com/workshops/from-bootcamp-to-...
# 1  https://codeup.com/featured/our-acquisition-of...
# 2  https://codeup.com/workshops/virtual/learn-to-...
# 3  https://codeup.com/workshops/virtual/learn-to-...
# 4  https://codeup.com/codeup-news/coming-soon-clo...
#
#                                                title date_published  \
# 0  From Bootcamp to Bootcamp | A Military Appreci...   Apr 27, 2022
# 1  Our Acquisition of the Rackspace Cloud Academy...   Apr 14, 2022
# 2  Learn to Code: HTML & CSS on 4/30\nApr 1, 2022...    Apr 1, 2022
# 3  Learn to Code: Python Workshop on 4/23\nMar 31...   Mar 31, 2022
# 4  Coming Soon: Cloud Administration\nMar 17, 202...   Mar 17, 2022
#
#                                             original  \
# 0  In honor of Military Appreciation Month, join ...
# 1  Just about a year ago on April 16th, 2021 we a...
# 2  HTML & CSS are the design building blocks of a...
# ...

# %%
# Out:
# Importing from csv
# Removed 21 stopwords
# Removed 20 stopwords
# Removed 20 stopwords
# Removed 23 stopwords
# Removed 24 stopwords
# Removed 22 stopwords
# Removed 24 stopwords
# Removed 19 stopwords
# Removed 22 stopwords
# Removed 16 stopwords
# Removed 18 stopwords
# Removed 19 stopwords
# Removed 17 stopwords
# Removed 26 stopwords
# Removed 21 stopwords
# Removed 27 stopwords
# Removed 20 stopwords
# Removed 28 stopwords
# Removed 24 stopwords
# Removed 22 stopwords
# Removed 26 stopwords
# Removed 25 stopwords
# Removed 21 stopwords
# Removed 20 stopwords
# Removed 25 stopwords
# Removed 18 stopwords
# Removed 18 stopwords
# Removed 21 stopwords
# Removed 22 stopwords
# Removed 15 stopwords
# Removed 23 stopwords
# Removed 21 stopwords
# Removed 24 stopwords
# Removed 25 stopwords
# Removed 23 stopwords
# Removed 24 stopwords
# Removed 27 stopwords
# Removed 19 stopwords
# Removed 20 stopwords
# Removed 22 stopwords
# Removed 19 stopwords
# Removed 17 stopwords
# ...

# %%
news_df.head()

# %% [markdown]
# ### 9
# - If your corpus is 493KB, would you prefer to use stemmed or lemmatized text?
# - If your corpus is 25MB, would you prefer to use stemmed or lemmatized text?
# - If your corpus is 200TB of text and you're charged by the megabyte for your hosted computational resources, would you prefer to use stemmed or lemmatized text?

# %% [markdown]
# Lemmatization is slower than stemming because it performs a check to see if the lemma is in the dictionary. Thus for smaller datasets lemmatization is fine but larger datasets may prefer stemming. Ultimately it will be judgement call as one method may produce more accurate results than the other, making the extra time spent lemmatizing worth it.
